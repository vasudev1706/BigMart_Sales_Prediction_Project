# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("Train.csv")

# %%
test = pd.read_csv("Test.csv")

# %%
train1 = train.copy()

# %%
train1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train1.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train1.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
sns.displot(train1["Item_Weight"],kde=True)
plt.title("density plot")
plt.show()

# %%
#finding outliers for Item weight and Outlet size(for filling the null values in the both column)

# %%
sns.boxplot(x="Item_Weight",data=train1)
# Out:
# <Axes: xlabel='Item_Weight'>

# %%
sns.barplot(x="Outlet_Size",y="Item_Outlet_Sales",data=train1)
plt.xlabel("Outlet_Szie")
plt.ylabel("outlet_type")
plt.show()

# %%
##as we dont have any outliers neither data is skewed we can use mean for filling the null values for item_weight and use mode for outlet_size we can use mode

# %%
train1["Item_Weight"].fillna(train1["Item_Weight"].mean(),inplace=True)

# %%
train1["Outlet_Size"].fillna(train1["Outlet_Size"].mode()[0],inplace=True)

# %%
train1[["Item_Weight","Outlet_Size"]].isna().sum()
# Out:
# Item_Weight    0
# Outlet_Size    0
# dtype: int64

# %%
#lets check duplicate values if any

# %%
train1.duplicated().sum()
# Out:
# 0

# %%
#as we can see there are no duplicate values in the dataset

# %%
train1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998      Medium               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002      Medium               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
#now lets findout the correlation between the features

# %%
numeric=train1.select_dtypes(include=["float64","int64"]).columns

# %%
correlation=(train1[numeric]).corr()

# %%
sns.heatmap(correlation,annot=True,cmap="coolwarm",fmt=".2f",linewidths=0.5)
plt.title("correlation matrix")
plt.show()

# %%
#as we can see there is no much correlation among the features expect item_mrp with outlet_sales

# %%
train1["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
 #as we have same feature repeated in item fat content we will combine them
 train1["Item_Fat_Content"]=train1["Item_Fat_Content"].replace(["Low Fat","LF"],"low fat")
 train1["Item_Fat_Content"]=train1["Item_Fat_Content"].replace("reg","Regular")

# %%
train1.Item_Fat_Content.unique()
# Out:
# array(['low fat', 'Regular'], dtype=object)

# %%
#now it will be easy to encode the Item_Fat_Content column as we have only 2 unique features, intially we had "low fat" in different ways, we have replaced them with "low fat" as all other "lowfat" feature were same.

# %%
train1.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   416
# Item_Fat_Content                2
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
sns.pairplot(train1[numeric])

# %%
train1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          low fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          low fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          low fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          low fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          low fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          low fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998      Medium               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002      Medium               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
#finding out the outliers

# %%
numeric_f=["Item_Weight","Item_Visibility","Item_MRP","Item_Outlet_Sales","Outlet_Establishment_Year"]
categorical_f=["Item_Identifier","Item_Fat_Content","Item_Type","Outlet_Identifier","Outlet_Size","Outlet_Location_Type","Outlet_Type",]

# %%
fig, axes = plt.subplots(nrows=len(numeric_f), ncols=1, figsize=(12, 6 * len(numeric_f)))

# Plotting boxplots for numeric columns
for i, column in enumerate(numeric_f):
    sns.boxplot(x=train1[column], ax=axes[i])
    axes[i].set_title(f'Boxplot for {column}')

# %%
#as we have outliers present in item_visibility and item_outlet_sale we will analysis them using other features

# %%
zero_visibility_counts = train1[train1['Item_Visibility'] == 0].groupby('Item_Type').size()
# Displaying the counts
print("Count of Item Types with Visibility Value = 0:")
print(zero_visibility_counts)
# Out:
# Count of Item Types with Visibility Value = 0:
# Item_Type
# Baking Goods             45
# Breads                   17
# Breakfast                 3
# Canned                   33
# Dairy                    38
# Frozen Foods             51
# Fruits and Vegetables    87
# Hard Drinks              17
# Health and Hygiene       33
# Household                51
# Meat                     20
# Others                   10
# Seafood                   4
# Snack Foods              68
# Soft Drinks              34
# Starchy Foods            15
# dtype: int64

# %%
train1["Item_Type"].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
#we will round off item visibility value by 2 decimal points

train1["Item_Visibility"]=train1["Item_Visibility"].round(2)

# %%
sns.histplot(train1['Item_Visibility'], kde=True, color='blue')
plt.title('Original Distribution')
plt.xlabel('Item Visibility')
# Out:
# Text(0.5, 0, 'Item Visibility')

# %%
#as we can see item_visibility is right skewed, now we will be using log transformation method to handle the outliers

# %%
train1["Item_Visibility_Log"]=np.log1p(train1["Item_Visibility"])

# %%
sns.boxplot(x="Item_Visibility_Log",data=train1)
# Out:
# <Axes: xlabel='Item_Visibility_Log'>

# %%
train1["Item_Visibility_Sqrt"]=np.sqrt(train1["Item_Visibility"])

# %%
sns.boxplot(x="Item_Visibility_Sqrt",data=train1)
# Out:
# <Axes: xlabel='Item_Visibility_Sqrt'>

# %%
from scipy.stats import boxcox
train1["Item_Visibility_Bcx"],_=boxcox(train1["Item_Visibility"]+1)

# %%
sns.boxplot(x="Item_Visibility_Bcx",data=train1)
# Out:
# <Axes: xlabel='Item_Visibility_Bcx'>

# %%
#as we have used log and squareroot transformation method both failed to reduce the outliers, so we have used boxcox method by which the outliers are reduced

# %%
sns.histplot(train1["Item_Outlet_Sales"],kde=True)
plt.show()

# %%
#as we can see the skewness in the data, will use different methods to handle outliers for outlet_sales

# %%
train1["Item_Outlet_Sales_bcx"],_=boxcox(train1["Item_Outlet_Sales"]+1)

# %%
sns.boxplot(x="Item_Outlet_Sales_bcx",data=train1)
# Out:
# <Axes: xlabel='Item_Outlet_Sales_bcx'>

# %%
from scipy.stats.mstats import winsorize
train1['Item_Outlet_Sales_win'] = winsorize(train1['Item_Outlet_Sales'], limits=[0.05, 0.05])

# %%
sns.boxplot(x="Item_Outlet_Sales_win",data=train1)
# Out:
# <Axes: xlabel='Item_Outlet_Sales_win'>

# %%
#so by using winsorize we got to reduce the outliers

# %%
train1.describe()
# Out:
# C:\Users\vasudev\anaconda3\1\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\vasudev\anaconda3\1\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\vasudev\anaconda3\1\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\vasudev\anaconda3\1\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\vasudev\anaconda3\1\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\vasudev\anaconda3\1\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\vasudev\anaconda3\1\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\vasudev\anaconda3\1\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\vasudev\anaconda3\1\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066164   140.992782                1997.831867
# std       4.226124         0.051641    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.030000    93.826500                1987.000000
# 50%      12.857645         0.050000   143.012800                1999.000000
# 75%      16.000000         0.090000   185.643700                2004.000000
# max      21.350000         0.330000   266.888400                2009.000000
#
#        Item_Outlet_Sales  Item_Visibility_Log  Item_Visibility_Sqrt  \
# count        8523.000000          8523.000000           8523.000000
# mean         2181.288914             0.062933              0.233673
# std          1706.499616             0.047261              0.107530
# min            33.290000             0.000000              0.000000
# 25%           834.247400             0.029559              0.173205
# 50%          1794.331000             0.048790              0.223607
# 75%          3101.296400             0.086178              0.300000
# max         13086.964800             0.285179              0.574456
#
#        Item_Visibility_Bcx  Item_Outlet_Sales_bcx  Item_Outlet_Sales_win
# count          8523.000000            8523.000000            8523.000000
# mean              0.043463              35.239871            2125.893932
# std               0.024985              11.757989            1539.948166
# min               0.000000               6.926177             188.421400
# 25%               0.026088              26.722748             834.247400
# 50%               0.039817              35.693263            1794.331000
# 75%               0.060786              43.726469            3101.296400
# max               0.105950              73.797658            5522.811000

# %%
#now let us drop the above unnecessary columns
train1.drop(columns=["Item_Visibility_Log","Item_Visibility_Sqrt","Item_Outlet_Sales_bcx"],axis=1,inplace=True)

# %%
train1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          low fat             0.02
# 1              DRC01        5.920          Regular             0.02
# 2              FDN15       17.500          low fat             0.02
# 3              FDX07       19.200          Regular             0.00
# 4              NCD19        8.930          low fat             0.00
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          low fat             0.06
# 8519           FDS36        8.380          Regular             0.05
# 8520           NCJ29       10.600          low fat             0.04
# 8521           FDN46        7.210          Regular             0.15
# 8522           DRG01       14.800          low fat             0.04
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998      Medium               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002      Medium               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Visibility_Bcx  \
# 0     Supermarket Type1          3735.1380             0.018202
# 1     Supermarket Type2           443.4228             0.018202
# 2     Supermarket Type1          2097.2700             0.018202
# 3         Grocery Store           732.3800             0.000000
# 4     Supermarket Type1           994.7052             0.000000
# ...                 ...                ...                  ...
# 8518  Supermarket Type1          2778.3834             0.045789
# 8519  Supermarket Type1           549.2850             0.039817
# 8520  Supermarket Type1          1193.1136             0.033270
# 8521  Supermarket Type2          1845.5976             0.081171
# 8522  Supermarket Type1           765.6700             0.033270
#
#       Item_Outlet_Sales_win
# 0                 3735.1380
# 1                  443.4228
# 2                 2097.2700
# 3                  732.3800
# 4                  994.7052
# ...                     ...
# 8518              2778.3834
# 8519               549.2850
# 8520              1193.1136
# 8521              1845.5976
# 8522               765.6700
#
# [8523 rows x 14 columns]

# %%
train1["Item_Type"].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
mapping = {
    "Dairy": "Food","Soft Drinks": "Drinks","Meat": "Food","Fruits and Vegetables": "Food","Household": "NonConsumable","Baking Goods": "NonConsumable","Snack Foods": "Food","Frozen Foods": "Food","Breakfast": "Food",  "Health and Hygiene": "NonConsumable", "Hard Drinks": "Drinks","Canned": "Food","Breads": "Food", "Starchy Foods": "Food","Others": "NonConsumable","Seafood": "Food"
      }

# %%
train1["Item_Type"] = train1["Item_Type"].str.strip().map(mapping)

# %%
train1["Item_Type"].unique()
# Out:
# array(['Food', 'Drinks', 'NonConsumable'], dtype=object)

# %%
 #checking the missing values if any
train1.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Item_Visibility_Bcx          0
# Item_Outlet_Sales_win        0
# dtype: int64

# %%
categorical_f=["Item_Fat_Content","Item_Type","Outlet_Identifier","Outlet_Establishment_Year","Outlet_Size","Outlet_Location_Type","Outlet_Type"]

# %%
for i, feature in enumerate(categorical_f, start=1):
    plt.figure(figsize=(16, 4 * ((len(train1.columns) - 1) // 3 + 1)))
    plt.subplot((len(train1.columns) - 1) // 3 + 1, 3, i)
    sns.barplot(x=feature, y='Item_Outlet_Sales', data=train1, ci=None)
    plt.title(f'{feature} vs Item_Outlet_Sales')
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

plt.tight_layout()
plt.show()
# Out:
# C:\Users\vasudev\AppData\Local\Temp\ipykernel_12260\2524396278.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=feature, y='Item_Outlet_Sales', data=train1, ci=None)
# C:\Users\vasudev\AppData\Local\Temp\ipykernel_12260\2524396278.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=feature, y='Item_Outlet_Sales', data=train1, ci=None)
# C:\Users\vasudev\AppData\Local\Temp\ipykernel_12260\2524396278.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=feature, y='Item_Outlet_Sales', data=train1, ci=None)
# C:\Users\vasudev\AppData\Local\Temp\ipykernel_12260\2524396278.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=feature, y='Item_Outlet_Sales', data=train1, ci=None)
# C:\Users\vasudev\AppData\Local\Temp\ipykernel_12260\2524396278.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=feature, y='Item_Outlet_Sales', data=train1, ci=None)
# C:\Users\vasudev\AppData\Local\Temp\ipykernel_12260\2524396278.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=feature, y='Item_Outlet_Sales', data=train1, ci=None)
# C:\Users\vasudev\AppData\Local\Temp\ipykernel_12260\2524396278.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=feature, y='Item_Outlet_Sales', data=train1, ci=None)

# %%
train1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          low fat             0.02
# 1              DRC01        5.920          Regular             0.02
# 2              FDN15       17.500          low fat             0.02
# 3              FDX07       19.200          Regular             0.00
# 4              NCD19        8.930          low fat             0.00
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          low fat             0.06
# 8519           FDS36        8.380          Regular             0.05
# 8520           NCJ29       10.600          low fat             0.04
# 8521           FDN46        7.210          Regular             0.15
# 8522           DRG01       14.800          low fat             0.04
#
#           Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0              Food  249.8092            OUT049                       1999
# 1            Drinks   48.2692            OUT018                       2009
# 2              Food  141.6180            OUT049                       1999
# 3              Food  182.0950            OUT010                       1998
# 4     NonConsumable   53.8614            OUT013                       1987
# ...             ...       ...               ...                        ...
# 8518           Food  214.5218            OUT013                       1987
# 8519  NonConsumable  108.1570            OUT045                       2002
# 8520  NonConsumable   85.1224            OUT035                       2004
# 8521           Food  103.1332            OUT018                       2009
# 8522         Drinks   75.4670            OUT046                       1997
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0         Medium               Tier 1  Supermarket Type1          3735.1380
# 1         Medium               Tier 3  Supermarket Type2           443.4228
# 2         Medium               Tier 1  Supermarket Type1          2097.2700
# 3         Medium               Tier 3      Grocery Store           732.3800
# 4           High               Tier 3  Supermarket Type1           994.7052
# ...          ...                  ...                ...                ...
# 8518        High               Tier 3  Supermarket Type1          2778.3834
# 8519      Medium               Tier 2  Supermarket Type1           549.2850
# 8520       Small               Tier 2  Supermarket Type1          1193.1136
# 8521      Medium               Tier 3  Supermarket Type2          1845.5976
# 8522       Small               Tier 1  Supermarket Type1           765.6700
#
#       Item_Visibility_Bcx  Item_Outlet_Sales_win
# 0                0.018202              3735.1380
# 1                0.018202               443.4228
# 2                0.018202              2097.2700
# 3                0.000000               732.3800
# 4                0.000000               994.7052
# ...                   ...                    ...
# 8518             0.045789              2778.3834
# 8519             0.039817               549.2850
# 8520             0.033270              1193.1136
# 8521             0.081171              1845.5976
# 8522             0.033270               765.6700
#
# [8523 rows x 14 columns]

# %%
plt.figure(figsize=(14, 8))
sns.countplot(x='Outlet_Identifier', hue='Outlet_Size', data=train1, palette='Set1', edgecolor='w', linewidth=0.5)
sns.countplot(x='Outlet_Identifier', hue='Outlet_Location_Type', data=train1, palette='Set2', edgecolor='w', linewidth=0.5, alpha=0.7)
sns.countplot(x='Outlet_Identifier', hue='Outlet_Type', data=train1, palette='Set3', edgecolor='w', linewidth=0.5, alpha=0.5)
plt.xlabel('Outlet Identifier')
plt.ylabel('Count')
plt.title('Comparison of Outlet Size, Location Type, and Outlet Type by Outlet Identifier')
plt.show()

# %%
# Group by Outlet_Identifier, Outlet_Size, Outlet_Type, and Outlet_Location_Type and count occurrences
grouped_counts = train1.groupby(['Outlet_Identifier', 'Outlet_Size', 'Outlet_Type', 'Outlet_Location_Type']).size().reset_index(name='Count')
print(grouped_counts)
# Out:
#   Outlet_Identifier Outlet_Size        Outlet_Type Outlet_Location_Type  Count
# 0            OUT010      Medium      Grocery Store               Tier 3    555
# 1            OUT013        High  Supermarket Type1               Tier 3    932
# 2            OUT017      Medium  Supermarket Type1               Tier 2    926
# 3            OUT018      Medium  Supermarket Type2               Tier 3    928
# 4            OUT019       Small      Grocery Store               Tier 1    528
# 5            OUT027      Medium  Supermarket Type3               Tier 3    935
# 6            OUT035       Small  Supermarket Type1               Tier 2    930
# 7            OUT045      Medium  Supermarket Type1               Tier 2    929
# 8            OUT046       Small  Supermarket Type1               Tier 1    930
# 9            OUT049      Medium  Supermarket Type1               Tier 1    930

# %%
grouped_outlets_count = train1.groupby(['Outlet_Size', 'Outlet_Type', 'Outlet_Location_Type'])['Outlet_Identifier'].nunique().reset_index(name='Outlet_Identifier_Count')
grouped_outlets_count
# Out:
#   Outlet_Size        Outlet_Type Outlet_Location_Type  Outlet_Identifier_Count
# 0        High  Supermarket Type1               Tier 3                        1
# 1      Medium      Grocery Store               Tier 3                        1
# 2      Medium  Supermarket Type1               Tier 1                        1
# 3      Medium  Supermarket Type1               Tier 2                        2
# 4      Medium  Supermarket Type2               Tier 3                        1
# 5      Medium  Supermarket Type3               Tier 3                        1
# 6       Small      Grocery Store               Tier 1                        1
# 7       Small  Supermarket Type1               Tier 1                        1
# 8       Small  Supermarket Type1               Tier 2                        1

# %%
train1.Outlet_Identifier.unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
# Creating a count plot for item types with low visibility
items_with_low_visibility = train1[train1['Item_Visibility'] <= 0]
plt.figure(figsize=(12, 6))
sns.countplot(x='Item_Type', data=items_with_low_visibility)
plt.xticks(rotation=45, ha='right')
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Food'), Text(1, 0, 'NonConsumable'), Text(2, 0, 'Drinks')])

# %% [markdown]
# #Above we have grouped the outlet identifier column using outlet type, outlet size and outlet location type

# %%
#performing encoding for required columns

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
train1["Item_Fat_Content"]
# Out:
# 0       low fat
# 1       Regular
# 2       low fat
# 3       Regular
# 4       low fat
#          ...
# 8518    low fat
# 8519    Regular
# 8520    low fat
# 8521    Regular
# 8522    low fat
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %%
fat_content_encoded = pd.get_dummies(train1['Item_Fat_Content'], prefix='Fat')
item_type_encoded = pd.get_dummies(train1['Item_Type'], prefix='Type')

# %%
train1 = pd.concat([train1, fat_content_encoded, item_type_encoded], axis=1)

# Drop the original 'Item_Fat_Content' and 'Item_Type' columns
train1 = train1.drop(['Item_Fat_Content', 'Item_Type'], axis=1)
train1
# Out:
#      Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0              FDA15        9.300             0.02  249.8092
# 1              DRC01        5.920             0.02   48.2692
# 2              FDN15       17.500             0.02  141.6180
# 3              FDX07       19.200             0.00  182.0950
# 4              NCD19        8.930             0.00   53.8614
# ...              ...          ...              ...       ...
# 8518           FDF22        6.865             0.06  214.5218
# 8519           FDS36        8.380             0.05  108.1570
# 8520           NCJ29       10.600             0.04   85.1224
# 8521           FDN46        7.210             0.15  103.1332
# 8522           DRG01       14.800             0.04   75.4670
#
#      Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0               OUT049                       1999      Medium
# 1               OUT018                       2009      Medium
# 2               OUT049                       1999      Medium
# 3               OUT010                       1998      Medium
# 4               OUT013                       1987        High
# ...                ...                        ...         ...
# 8518            OUT013                       1987        High
# 8519            OUT045                       2002      Medium
# 8520            OUT035                       2004       Small
# 8521            OUT018                       2009      Medium
# 8522            OUT046                       1997       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0                  Tier 1  Supermarket Type1          3735.1380
# 1                  Tier 3  Supermarket Type2           443.4228
# 2                  Tier 1  Supermarket Type1          2097.2700
# 3                  Tier 3      Grocery Store           732.3800
# 4                  Tier 3  Supermarket Type1           994.7052
# ...                   ...                ...                ...
# 8518               Tier 3  Supermarket Type1          2778.3834
# 8519               Tier 2  Supermarket Type1           549.2850
# 8520               Tier 2  Supermarket Type1          1193.1136
# 8521               Tier 3  Supermarket Type2          1845.5976
# 8522               Tier 1  Supermarket Type1           765.6700
#
#       Item_Visibility_Bcx  Item_Outlet_Sales_win  Fat_Regular  Fat_low fat  \
# 0                0.018202              3735.1380            0            1
# 1                0.018202               443.4228            1            0
# 2                0.018202              2097.2700            0            1
# 3                0.000000               732.3800            1            0
# 4                0.000000               994.7052            0            1
# ...                   ...                    ...          ...          ...
# 8518             0.045789              2778.3834            0            1
# 8519             0.039817               549.2850            1            0
# 8520             0.033270              1193.1136            0            1
# 8521             0.081171              1845.5976            1            0
# 8522             0.033270               765.6700            0            1
#
#       Type_Drinks  Type_Food  Type_NonConsumable
# 0               0          1                   0
# 1               1          0                   0
# 2               0          1                   0
# 3               0          1                   0
# 4               0          0                   1
# ...           ...        ...                 ...
# 8518            0          1                   0
# 8519            0          0                   1
# 8520            0          0                   1
# 8521            0          1                   0
# 8522            1          0                   0
#
# [8523 rows x 17 columns]

# %%
# i am mapping the other features as they are in hirarical way it will be easy to map them

# %%
map={"Small":1,"Medium":2,"High":3}

# %%
train1["Outlet_Size"]=train1["Outlet_Size"].map(map)

# %%
map1={"Tier 1":1,"Tier 2":2,"Tier 3":3}

# %%
train1["Outlet_Location_Type"]=train1["Outlet_Location_Type"].map(map1)

# %%
map2={"Supermarket Type1":1,"Supermarket Type2":2,"Supermarket Type3":3,"Grocery Store":4}

# %%
train1["Outlet_Type"]=train1["Outlet_Type"].map(map2)

# %%
train1["Item_Identifier"]=le.fit_transform(train1["Item_Identifier"])

# %%
train1["Outlet_Identifier"]=le.fit_transform(train1["Outlet_Identifier"])

# %%
#now lets drop "Item_Visibility" and "Item_Outlet_Sales" as we have the updated columns for them without outliers present

# %%
train1.drop(columns=["Item_Visibility","Item_Outlet_Sales"],axis=1,inplace=True)

# %% [markdown]
# Scaling the data

# %%
train_norm = train1.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
train1[["Item_Weight","Item_MRP","Outlet_Establishment_Year","Item_Visibility_Bcx"]]=sc.fit_transform(train1[["Item_Weight","Item_MRP","Outlet_Establishment_Year","Item_Visibility_Bcx"]])

# %%
train1
# Out:
#       Item_Identifier  Item_Weight  Item_MRP  Outlet_Identifier  \
# 0                 156    -0.841872  1.747454                  9
# 1                   8    -1.641706 -1.489023                  3
# 2                 662     1.098554  0.010040                  9
# 3                1121     1.500838  0.660050                  0
# 4                1297    -0.929428 -1.399220                  1
# ...               ...          ...       ...                ...
# 8518              370    -1.418084  1.180783                  1
# 8519              897    -1.059578 -0.527301                  7
# 8520             1357    -0.534243 -0.897208                  6
# 8521              681    -1.336444 -0.607977                  3
# 8522               50     0.459634 -1.052261                  8
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                      0.139541            2                     1
# 1                      1.334103            2                     3
# 2                      0.139541            2                     1
# 3                      0.020085            2                     3
# 4                     -1.293934            3                     3
# ...                         ...          ...                   ...
# 8518                  -1.293934            3                     3
# 8519                   0.497909            2                     2
# 8520                   0.736822            1                     2
# 8521                   1.334103            2                     3
# 8522                  -0.099372            1                     1
#
#       Outlet_Type  Item_Visibility_Bcx  Item_Outlet_Sales_win  Fat_Regular  \
# 0               1            -1.011111              3735.1380            0
# 1               2            -1.011111               443.4228            1
# 2               1            -1.011111              2097.2700            0
# 3               4            -1.739687               732.3800            1
# 4               1            -1.739687               994.7052            0
# ...           ...                  ...                    ...          ...
# 8518            1             0.093107              2778.3834            0
# 8519            1            -0.145953               549.2850            1
# 8520            1            -0.407987              1193.1136            0
# 8521            2             1.509301              1845.5976            1
# 8522            1            -0.407987               765.6700            0
#
#       Fat_low fat  Type_Drinks  Type_Food  Type_NonConsumable
# 0               1            0          1                   0
# 1               0            1          0                   0
# 2               1            0          1                   0
# 3               0            0          1                   0
# 4               1            0          0                   1
# ...           ...          ...        ...                 ...
# 8518            1            0          1                   0
# 8519            0            0          0                   1
# 8520            1            0          0                   1
# 8521            0            0          1                   0
# 8522            1            1          0                   0
#
# [8523 rows x 15 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()

# %%
train_norm
# Out:
#       Item_Identifier  Item_Weight  Item_MRP  Outlet_Identifier  \
# 0                 156        9.300  249.8092                  9
# 1                   8        5.920   48.2692                  3
# 2                 662       17.500  141.6180                  9
# 3                1121       19.200  182.0950                  0
# 4                1297        8.930   53.8614                  1
# ...               ...          ...       ...                ...
# 8518              370        6.865  214.5218                  1
# 8519              897        8.380  108.1570                  7
# 8520             1357       10.600   85.1224                  6
# 8521              681        7.210  103.1332                  3
# 8522               50       14.800   75.4670                  8
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                          1999            2                     1
# 1                          2009            2                     3
# 2                          1999            2                     1
# 3                          1998            2                     3
# 4                          1987            3                     3
# ...                         ...          ...                   ...
# 8518                       1987            3                     3
# 8519                       2002            2                     2
# 8520                       2004            1                     2
# 8521                       2009            2                     3
# 8522                       1997            1                     1
#
#       Outlet_Type  Item_Visibility_Bcx  Item_Outlet_Sales_win  Fat_Regular  \
# 0               1             0.018202              3735.1380            0
# 1               2             0.018202               443.4228            1
# 2               1             0.018202              2097.2700            0
# 3               4             0.000000               732.3800            1
# 4               1             0.000000               994.7052            0
# ...           ...                  ...                    ...          ...
# 8518            1             0.045789              2778.3834            0
# 8519            1             0.039817               549.2850            1
# 8520            1             0.033270              1193.1136            0
# 8521            2             0.081171              1845.5976            1
# 8522            1             0.033270               765.6700            0
#
#       Fat_low fat  Type_Drinks  Type_Food  Type_NonConsumable
# 0               1            0          1                   0
# 1               0            1          0                   0
# 2               1            0          1                   0
# 3               0            0          1                   0
# 4               1            0          0                   1
# ...           ...          ...        ...                 ...
# 8518            1            0          1                   0
# 8519            0            0          0                   1
# 8520            1            0          0                   1
# 8521            0            0          1                   0
# 8522            1            1          0                   0
#
# [8523 rows x 15 columns]

# %%
train_norm[["Item_Weight","Item_MRP","Outlet_Establishment_Year","Item_Visibility_Bcx"]] = mms.fit_transform(train_norm[["Item_Weight","Item_MRP","Outlet_Establishment_Year","Item_Visibility_Bcx"]])

# %%
train1[["Item_Identifier","Outlet_Identifier","Outlet_Size","Outlet_Location_Type","Outlet_Type"]]= sc.fit_transform(train1[["Item_Identifier","Outlet_Identifier","Outlet_Size","Outlet_Location_Type","Outlet_Type"]])

# %% [markdown]
# #EDA FOR TEST DATASET

# %%
test1=test.copy()

# %%
test1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007         NaN               Tier 2
# 2                          1998         NaN               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
test1.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
test1["Item_Weight"].fillna(test1["Item_Weight"].mean(),inplace=True)

# %%
test1["Outlet_Size"].fillna(test1["Outlet_Size"].mode()[0],inplace=True)

# %%
test1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58    20.750000          Low Fat         0.007565
# 1              FDW14     8.300000              reg         0.038428
# 2              NCN55    14.600000          Low Fat         0.099575
# 3              FDQ58     7.315000          Low Fat         0.015388
# 4              FDY38    12.695633          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58    10.500000          Regular         0.013496
# 5677           FDD47     7.600000          Regular         0.142991
# 5678           NCO17    10.000000          Low Fat         0.073529
# 5679           FDJ26    15.300000          Regular         0.000000
# 5680           FDU37     9.500000          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007      Medium               Tier 2
# 2                          1998      Medium               Tier 3
# 3                          2007      Medium               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002      Medium               Tier 2
# 5679                       2007      Medium               Tier 2
# 5680                       2002      Medium               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
test1["Item_Fat_Content"]=test1["Item_Fat_Content"].replace(["Low Fat","LF"],"low fat")
test1["Item_Fat_Content"]=test1["Item_Fat_Content"].replace("reg","Regular")

# %%
mapping = {
    "Dairy": "Food","Soft Drinks": "Drinks","Meat": "Food","Fruits and Vegetables": "Food","Household": "NonConsumable","Baking Goods": "NonConsumable","Snack Foods": "Food","Frozen Foods": "Food","Breakfast": "Food",  "Health and Hygiene": "NonConsumable", "Hard Drinks": "Drinks","Canned": "Food","Breads": "Food", "Starchy Foods": "Food","Others": "NonConsumable","Seafood": "Food"
      }

# %%
test1["Item_Type"]=test1["Item_Type"].str.strip().map(mapping)

# %%
test1["Item_Fat_Content"]=le.fit_transform(test1["Item_Fat_Content"])

# %%
map={"Small":1,"Medium":2,"High":3}

# %%
test1["Outlet_Size"]=test1["Outlet_Size"].map(map)

# %%
map1={"Tier 1":1,"Tier 2":2,"Tier 3":3}

# %%
test1["Outlet_Location_Type"]=test1["Outlet_Location_Type"].map(map1)

# %%
map2={"Supermarket Type1":1,"Supermarket Type2":2,"Supermarket Type3":3,"Grocery Store":4}

# %%
test1["Outlet_Type"]=test1["Outlet_Type"].map(map2)

# %%
test1["Item_Identifier"]=le.fit_transform(test1["Item_Identifier"])

# %%
test1["Outlet_Identifier"]=le.fit_transform(test1["Outlet_Identifier"])

# %%
map3={"Food":1,"Drinks":2,"NonConsumable":3}

# %%
test1["Item_Type"]=test1["Item_Type"].map(map3)

# %%
test1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                1103    20.750000                 1         0.007565
# 1                1067     8.300000                 0         0.038428
# 2                1406    14.600000                 1         0.099575
# 3                 809     7.315000                 1         0.015388
# 4                1184    12.695633                 0         0.118599
# ...               ...          ...               ...              ...
# 5676              231    10.500000                 0         0.013496
# 5677              306     7.600000                 0         0.142991
# 5678             1412    10.000000                 1         0.073529
# 5679              517    15.300000                 0         0.000000
# 5680              987     9.500000                 0         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             1  107.8622                  9                       1999
# 1             1   87.3198                  2                       2007
# 2             3  241.7538                  0                       1998
# 3             1  155.0340                  2                       2007
# 4             1  234.2300                  5                       1985
# ...         ...       ...                ...                        ...
# 5676          1  141.3154                  8                       1997
# 5677          1  169.1448                  3                       2009
# 5678          3  118.7440                  7                       2002
# 5679          1  214.6218                  2                       2007
# 5680          1   79.7960                  7                       2002
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               2                     1            1
# 1               2                     2            1
# 2               2                     3            4
# 3               2                     2            1
# 4               2                     3            3
# ...           ...                   ...          ...
# 5676            1                     1            1
# 5677            2                     3            2
# 5678            2                     2            1
# 5679            2                     2            1
# 5680            2                     2            1
#
# [5681 rows x 11 columns]

# %% [markdown]
# #Model Building

# %%
train1
# Out:
#       Item_Identifier  Item_Weight  Item_MRP  Outlet_Identifier  \
# 0           -1.388514    -0.841872  1.747454           1.507813
# 1           -1.717991    -1.641706 -1.489023          -0.607071
# 2           -0.262057     1.098554  0.010040           1.507813
# 3            0.759769     1.500838  0.660050          -1.664513
# 4            1.151580    -0.929428 -1.399220          -1.312032
# ...               ...          ...       ...                ...
# 8518        -0.912107    -1.418084  1.180783          -1.312032
# 8519         0.261100    -1.059578 -0.527301           0.802852
# 8520         1.285152    -0.534243 -0.897208           0.450371
# 8521        -0.219759    -1.336444 -0.607977          -0.607071
# 8522        -1.624491     0.459634 -1.052261           1.155333
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                      0.139541     0.284581             -1.369334
# 1                      1.334103     0.284581              1.091569
# 2                      0.139541     0.284581             -1.369334
# 3                      0.020085     0.284581              1.091569
# 4                     -1.293934     1.950437              1.091569
# ...                         ...          ...                   ...
# 8518                  -1.293934     1.950437              1.091569
# 8519                   0.497909     0.284581             -0.138882
# 8520                   0.736822    -1.381274             -0.138882
# 8521                   1.334103     0.284581              1.091569
# 8522                  -0.099372    -1.381274             -1.369334
#
#       Outlet_Type  Item_Visibility_Bcx  Item_Outlet_Sales_win  Fat_Regular  \
# 0       -0.650957            -1.011111              3735.1380            0
# 1        0.266541            -1.011111               443.4228            1
# 2       -0.650957            -1.011111              2097.2700            0
# 3        2.101536            -1.739687               732.3800            1
# 4       -0.650957            -1.739687               994.7052            0
# ...           ...                  ...                    ...          ...
# 8518    -0.650957             0.093107              2778.3834            0
# 8519    -0.650957            -0.145953               549.2850            1
# 8520    -0.650957            -0.407987              1193.1136            0
# 8521     0.266541             1.509301              1845.5976            1
# 8522    -0.650957            -0.407987               765.6700            0
#
#       Fat_low fat  Type_Drinks  Type_Food  Type_NonConsumable
# 0               1            0          1                   0
# 1               0            1          0                   0
# 2               1            0          1                   0
# 3               0            0          1                   0
# 4               1            0          0                   1
# ...           ...          ...        ...                 ...
# 8518            1            0          1                   0
# 8519            0            0          0                   1
# 8520            1            0          0                   1
# 8521            0            0          1                   0
# 8522            1            1          0                   0
#
# [8523 rows x 15 columns]

# %%
#now lets split the data into independent and dependent features

# %%
x = train1.drop(columns=["Item_Outlet_Sales_win"])
y = train1["Item_Outlet_Sales_win"]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# #Random Forest

# %%
# now lets import random forest model

# %%
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor()

# %%
# Hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
random_search = RandomizedSearchCV(estimator=RF, param_distributions=param_grid, n_iter=10, cv=5, scoring='r2', n_jobs=-1, random_state=42)
random_search.fit(xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [None, 10, 20, 30],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    random_state=42, scoring='r2')

# %%
random_params = random_search.best_params_

# %%
RF_random = RandomForestRegressor(**random_params)
RF_random.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=4)

# %%
ypred_random=RF_random.predict(xtest)

# %%
RF_train_score= RF_random.score(xtrain,ytrain)
RF_train_score
# Out:
# 0.699885978186744

# %%
mse = mean_squared_error(ytest,ypred_random)
rmse = np.sqrt(mse)
r2_ = r2_score(ytest,ypred_random)
print(f"mean_squared_error : {mse}")
print(f"root_mean_square_error : {rmse}")
print(f"r_square : {r2_}")
# Out:
# mean_squared_error : 856908.6133486433
# root_mean_square_error : 925.6935850207904
# r_square : 0.621297014461139

# %%
#Calculating the adjusted R-squared value
n = len(y)
k = x.shape[1] - 1
adjusted_rsquared = 1 - (1 - r2_) * (n - 1) / (n - k - 1)
print(f"R-squared: {r2_}")
print(f"Adjusted R-squared: {adjusted_rsquared}")
# Out:
# R-squared: 0.621297014461139
# Adjusted R-squared: 0.6207184342740424

# %%
#cross val score
from sklearn.model_selection import cross_val_score, KFold

# %%
kf1 = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
cv_score_ = cross_val_score(RF_random, x, y, cv=kf1, scoring='r2')
print(f"Cross Val Score:{cv_score_}")
print(f'Mean R-squared: {np.mean(cv_score_)}')
# Out:
# Cross Val Score:[0.62164593 0.61034529 0.60672212 0.59979666 0.59367496]
# Mean R-squared: 0.606436988574543

# %%
#data scaled using normalization
x1 = train_norm.drop(columns=["Item_Outlet_Sales_win"])
y1 = train_norm["Item_Outlet_Sales_win"]

# %%
xtrain1, xtest1, ytrain1, ytest1 = train_test_split(x1, y1, test_size=0.2, random_state=42)

# %%
random_search_ = RandomizedSearchCV(estimator=RF, param_distributions=param_grid, n_iter=10, cv=5, scoring='r2', n_jobs=-1, random_state=42)
random_search_.fit(xtrain1, ytrain1)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [None, 10, 20, 30],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    random_state=42, scoring='r2')

# %%
random_params_ = random_search_.best_params_

# %%
RF_random_ = RandomForestRegressor(**random_params_)
RF_random_.fit(xtrain1, ytrain1)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=4)

# %%
ypred_random_=RF_random_.predict(xtest1)

# %%
ypred_random_
# Out:
# array([1080.20460946,  712.49686922,  683.49864029, ...,  688.32132322,
#         666.55425542, 1655.05892358])

# %%
mse = mean_squared_error(ytest1,ypred_random_)
rmse = np.sqrt(mse)
_r2_ = r2_score(ytest1,ypred_random_)
print(f"mean_squared_error : {mse}")
print(f"root_mean_square_error : {rmse}")
print(f"r_square : {_r2_}")
# Out:
# mean_squared_error : 851637.7126993812
# root_mean_square_error : 922.8421927390301
# r_square : 0.6236264411715953

# %%
#Calculating the adjusted R-squared value
n = len(y)
k = x.shape[1] - 1
adjusted_rsquared = 1 - (1 - _r2_) * (n - 1) / (n - k - 1)
print(f"R-squared: {_r2_}")
print(f"Adjusted R-squared: {adjusted_rsquared}")
# Out:
# R-squared: 0.6236264411715953
# Adjusted R-squared: 0.6230514198688841

# %%
#cross val score

# %%
kf2 = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
cv_score_1 = cross_val_score(RF_random, x, y, cv=kf2, scoring='r2')
print(f"Cross Val Score:{cv_score_1}")
print(f'Mean R-squared: {np.mean(cv_score_1)}')
# Out:
# Cross Val Score:[0.62352861 0.60735623 0.60771224 0.60115955 0.59435217]
# Mean R-squared: 0.6068217602767614

# %%
#Calculating MAPE
def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - ypred_random_) / y_true)) * 100
mape = calculate_mape(ytest1, ypred_random_)
print(f"MAPE: {mape}")
# Out:
# MAPE: 51.178413666149304

# %% [markdown]
# #SVR

# %%
#we will try to use SVM model for model building

# %%
from sklearn.svm import SVR

# %%
svm_model= SVR(kernel="linear")

# %%
svm_model.fit(xtrain,ytrain)
# Out:
# SVR(kernel='linear')

# %%
ypred_svm = svm_model.predict(xtest)

# %%
train_score= svm_model.score(xtrain,ytrain)
train_score
# Out:
# 0.45050409402315805

# %%
mse = mean_squared_error(ytest,ypred_svm)
rmse = np.sqrt(mse)
r2 = r2_score(ytest,ypred_svm)

# %%
print(f"mean_squared_error : {mse}")
print(f"root_mean_square_error : {rmse}")
print(f"r_square : {r2}")
# Out:
# mean_squared_error : 1223022.7757543311
# root_mean_square_error : 1105.9036014745277
# r_square : 0.45949618273734516

# %%
#Calculating the adjusted R-squared value
n = len(y1)
k = x1.shape[1] - 1
adjusted_rsquared = 1 - (1 - r2) * (n - 1) / (n - k - 1)
print(f"R-squared: {r2}")
print(f"Adjusted R-squared: {adjusted_rsquared}")
# Out:
# R-squared: 0.45949618273734516
# Adjusted R-squared: 0.4586704041941069

# %%
#normalized data
x2 = train_norm.drop(columns=["Item_Outlet_Sales_win"])
y2 = train_norm["Item_Outlet_Sales_win"]

# %%
xtrain2, xtest2, ytrain2, ytest2 = train_test_split(x2, y2, test_size=0.2, random_state=42)

# %%
svm_model.fit(xtrain2,ytrain2)
# Out:
# SVR(kernel='linear')

# %%
ypred2 = svm_model.predict(xtest2)

# %%
mse2 = mean_squared_error(ytest2,ypred2)
rmse2 = np.sqrt(mse)
r22 = r2_score(ytest2,ypred2)

# %%
print(f"mean_squared_error : {mse2}")
print(f"root_mean_square_error : {rmse2}")
print(f"r_square : {r22}")
# Out:
# mean_squared_error : 1717185.9374854062
# root_mean_square_error : 1105.9036014745277
# r_square : 0.24110525775928038

# %%
#Calculating the adjusted R-squared value
n = len(y2)
k = x2.shape[1] - 1
adjusted_rsquared = 1 - (1 - r22) * (n - 1) / (n - k - 1)
print(f"R-squared: {r22}")
print(f"Adjusted R-squared: {adjusted_rsquared}")
# Out:
# R-squared: 0.24110525775928038
# Adjusted R-squared: 0.23994582284928745

# %%
#performing cross val score

# %%
from sklearn.model_selection import cross_val_score, KFold

# %%
# Creating KFold object
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
cv_score = cross_val_score(svm_model, x, y, cv=kf, scoring='r2')

# %%
print(f"Cross Val Score:{cv_score}")
print(f'Mean R-squared: {np.mean(cv_score)}')
# Out:
# Cross Val Score:[0.45949617 0.44679734 0.45601144 0.44841978 0.44119684]
# Mean R-squared: 0.4503843138278265

# %%
#calculating the mape
def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - ypred_svm) / y_true)) * 100
mape = calculate_mape(ytest, ypred_svm)
print(f"MAPE: {mape}")
# Out:
# MAPE: 79.43368851691841

# %% [markdown]
# #XGBoost

# %%
#lets use XGboost model
# !pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/24/ec/ad387100fa3cc2b9b81af0829b5ecfe75ec5bb19dd7c19d4fea06fb81802/xgboost-2.0.3-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\vasudev\anaconda3\1\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\vasudev\anaconda3\1\lib\site-packages (from xgboost) (1.10.1)
# Downloading xgboost-2.0.3-py3-none-win_amd64.whl (99.8 MB)
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/99.8 MB 6.8 MB/s eta 0:00:15
#    ---------------------------------------- 0.7/99.8 MB 7.8 MB/s eta 0:00:13
#    ---------------------------------------- 1.1/99.8 MB 7.9 MB/s eta 0:00:13
#     --------------------------------------- 1.5/99.8 MB 8.2 MB/s eta 0:00:13
#     --------------------------------------- 1.9/99.8 MB 8.2 MB/s eta 0:00:12
#     --------------------------------------- 2.4/99.8 MB 8.6 MB/s eta 0:00:12
#    - -------------------------------------- 2.9/99.8 MB 8.8 MB/s eta 0:00:12
#    - -------------------------------------- 3.5/99.8 MB 9.2 MB/s eta 0:00:11
#    - -------------------------------------- 3.9/99.8 MB 9.3 MB/s eta 0:00:11
#    - -------------------------------------- 4.5/99.8 MB 9.6 MB/s eta 0:00:10
#    - -------------------------------------- 4.9/99.8 MB 9.5 MB/s eta 0:00:10
#    -- ------------------------------------- 5.4/99.8 MB 9.5 MB/s eta 0:00:10
#    -- ------------------------------------- 5.9/99.8 MB 9.6 MB/s eta 0:00:10
#    -- ------------------------------------- 6.2/99.8 MB 9.5 MB/s eta 0:00:10
#    -- ------------------------------------- 6.7/99.8 MB 9.6 MB/s eta 0:00:10
#    -- ------------------------------------- 7.2/99.8 MB 9.6 MB/s eta 0:00:10
#    --- ------------------------------------ 7.8/99.8 MB 9.8 MB/s eta 0:00:10
#    --- ------------------------------------ 8.2/99.8 MB 9.5 MB/s eta 0:00:10
#    --- ------------------------------------ 8.8/99.8 MB 9.8 MB/s eta 0:00:10
#    --- ------------------------------------ 9.2/99.8 MB 9.8 MB/s eta 0:00:10
#    --- ------------------------------------ 9.8/99.8 MB 9.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 10.2/99.8 MB 9.7 MB/s eta 0:00:10
#    ---- ----------------------------------- 10.6/99.8 MB 10.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 11.2/99.8 MB 9.9 MB/s eta 0:00:09
#    ---- ----------------------------------- 11.6/99.8 MB 10.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 12.1/99.8 MB 10.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 12.5/99.8 MB 10.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 12.9/99.8 MB 9.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 13.4/99.8 MB 9.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 13.9/99.8 MB 10.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 14.5/99.8 MB 10.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 14.9/99.8 MB 9.9 MB/s eta 0:00:09
#    ------ --------------------------------- 15.3/99.8 MB 10.1 MB/s eta 0:00:09
#    ------ --------------------------------- 15.8/99.8 MB 9.9 MB/s eta 0:00:09
#    ------ --------------------------------- 16.3/99.8 MB 10.1 MB/s eta 0:00:09
#    ------ --------------------------------- 16.9/99.8 MB 10.2 MB/s eta 0:00:09
#    ------ --------------------------------- 17.3/99.8 MB 10.2 MB/s eta 0:00:09
#    ------- -------------------------------- 17.9/99.8 MB 10.2 MB/s eta 0:00:09
#    ------- -------------------------------- 18.4/99.8 MB 10.1 MB/s eta 0:00:09
#    ------- -------------------------------- 18.9/99.8 MB 10.2 MB/s eta 0:00:08
#    ------- -------------------------------- 19.4/99.8 MB 10.2 MB/s eta 0:00:08
#    ------- -------------------------------- 19.9/99.8 MB 10.2 MB/s eta 0:00:08
#    -------- ------------------------------- 20.4/99.8 MB 10.2 MB/s eta 0:00:08
#    -------- ------------------------------- 20.8/99.8 MB 10.2 MB/s eta 0:00:08
#    -------- ------------------------------- 21.2/99.8 MB 10.2 MB/s eta 0:00:08
#    -------- ------------------------------- 21.7/99.8 MB 10.4 MB/s eta 0:00:08
#    -------- ------------------------------- 22.0/99.8 MB 10.2 MB/s eta 0:00:08
#    -------- ------------------------------- 22.4/99.8 MB 10.2 MB/s eta 0:00:08
#    --------- ------------------------------ 22.8/99.8 MB 10.4 MB/s eta 0:00:08
#    --------- ------------------------------ 23.1/99.8 MB 10.4 MB/s eta 0:00:08
#    --------- ------------------------------ 23.5/99.8 MB 10.4 MB/s eta 0:00:08
#    --------- ------------------------------ 24.1/99.8 MB 10.2 MB/s eta 0:00:08
#    --------- ------------------------------ 24.5/99.8 MB 10.2 MB/s eta 0:00:08
#    --------- ------------------------------ 24.7/99.8 MB 10.2 MB/s eta 0:00:08
#    ---------- ----------------------------- 25.2/99.8 MB 10.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 25.3/99.8 MB 9.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 25.8/99.8 MB 9.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 26.3/99.8 MB 9.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 26.7/99.8 MB 9.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 27.2/99.8 MB 9.9 MB/s eta 0:00:08
#    ----------- ---------------------------- 27.6/99.8 MB 9.9 MB/s eta 0:00:08
#    ----------- ---------------------------- 27.9/99.8 MB 9.9 MB/s eta 0:00:08
#    ----------- ---------------------------- 28.5/99.8 MB 10.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 28.9/99.8 MB 9.9 MB/s eta 0:00:08
#    ----------- ---------------------------- 29.4/99.8 MB 9.9 MB/s eta 0:00:08
#    ----------- ---------------------------- 29.8/99.8 MB 9.8 MB/s eta 0:00:08
#    ------------ --------------------------- 30.3/99.8 MB 9.8 MB/s eta 0:00:08
#    ------------ --------------------------- 30.8/99.8 MB 9.6 MB/s eta 0:00:08
#    ------------ --------------------------- 31.3/99.8 MB 9.8 MB/s eta 0:00:07
#    ------------ --------------------------- 31.7/99.8 MB 9.6 MB/s eta 0:00:08
#    ------------ --------------------------- 32.2/99.8 MB 9.6 MB/s eta 0:00:08
#    ------------- -------------------------- 32.8/99.8 MB 9.8 MB/s eta 0:00:07
#    ------------- -------------------------- 33.3/99.8 MB 9.9 MB/s eta 0:00:07
#    ------------- -------------------------- 33.7/99.8 MB 9.8 MB/s eta 0:00:07
#    ------------- -------------------------- 34.2/99.8 MB 9.6 MB/s eta 0:00:07
#    ------------- -------------------------- 34.7/99.8 MB 9.8 MB/s eta 0:00:07
#    -------------- ------------------------- 35.2/99.8 MB 9.8 MB/s eta 0:00:07
#    -------------- ------------------------- 35.6/99.8 MB 10.1 MB/s eta 0:00:07
#    -------------- ------------------------- 36.1/99.8 MB 10.2 MB/s eta 0:00:07
#    -------------- ------------------------- 36.6/99.8 MB 9.9 MB/s eta 0:00:07
#    -------------- ------------------------- 37.1/99.8 MB 10.1 MB/s eta 0:00:07
#    --------------- ------------------------ 37.6/99.8 MB 10.1 MB/s eta 0:00:07
#    --------------- ------------------------ 38.0/99.8 MB 9.9 MB/s eta 0:00:07
#    --------------- ------------------------ 38.6/99.8 MB 10.1 MB/s eta 0:00:07
#    --------------- ------------------------ 39.1/99.8 MB 10.1 MB/s eta 0:00:07
#    --------------- ------------------------ 39.6/99.8 MB 10.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 40.0/99.8 MB 10.4 MB/s eta 0:00:06
#    ---------------- ----------------------- 40.5/99.8 MB 10.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 41.0/99.8 MB 10.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 41.4/99.8 MB 10.1 MB/s eta 0:00:06
#    ---------------- ----------------------- 41.9/99.8 MB 10.1 MB/s eta 0:00:06
#    ---------------- ----------------------- 42.3/99.8 MB 10.4 MB/s eta 0:00:06
#    ----------------- ---------------------- 42.7/99.8 MB 10.2 MB/s eta 0:00:06
#    ----------------- ---------------------- 43.2/99.8 MB 10.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 43.5/99.8 MB 10.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 43.9/99.8 MB 10.2 MB/s eta 0:00:06
#    ----------------- ---------------------- 44.3/99.8 MB 10.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 44.6/99.8 MB 10.1 MB/s eta 0:00:06
#    ------------------ --------------------- 45.1/99.8 MB 10.1 MB/s eta 0:00:06
#    ------------------ --------------------- 45.5/99.8 MB 10.1 MB/s eta 0:00:06
#    ------------------ --------------------- 45.9/99.8 MB 10.1 MB/s eta 0:00:06
#    ------------------ --------------------- 46.5/99.8 MB 10.2 MB/s eta 0:00:06
#    ------------------ --------------------- 46.9/99.8 MB 10.1 MB/s eta 0:00:06
#    ------------------ --------------------- 47.3/99.8 MB 10.1 MB/s eta 0:00:06
#    ------------------- -------------------- 47.8/99.8 MB 10.2 MB/s eta 0:00:06
#    ------------------- -------------------- 48.1/99.8 MB 10.2 MB/s eta 0:00:06
#    ------------------- -------------------- 48.6/99.8 MB 9.9 MB/s eta 0:00:06
#    ------------------- -------------------- 49.1/99.8 MB 9.8 MB/s eta 0:00:06
#    ------------------- -------------------- 49.7/99.8 MB 9.9 MB/s eta 0:00:06
#    -------------------- ------------------- 50.2/99.8 MB 10.1 MB/s eta 0:00:05
#    -------------------- ------------------- 50.6/99.8 MB 9.9 MB/s eta 0:00:05
#    -------------------- ------------------- 51.2/99.8 MB 10.1 MB/s eta 0:00:05
#    -------------------- ------------------- 51.6/99.8 MB 10.1 MB/s eta 0:00:05
#    -------------------- ------------------- 52.1/99.8 MB 10.1 MB/s eta 0:00:05
#    --------------------- ------------------ 52.6/99.8 MB 10.1 MB/s eta 0:00:05
#    --------------------- ------------------ 53.2/99.8 MB 10.2 MB/s eta 0:00:05
#    --------------------- ------------------ 53.6/99.8 MB 9.9 MB/s eta 0:00:05
#    --------------------- ------------------ 54.5/99.8 MB 10.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 55.0/99.8 MB 10.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 55.4/99.8 MB 10.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 55.7/99.8 MB 10.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 56.2/99.8 MB 10.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 56.7/99.8 MB 10.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 57.2/99.8 MB 10.2 MB/s eta 0:00:05
#    ----------------------- ---------------- 57.6/99.8 MB 10.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 58.1/99.8 MB 10.2 MB/s eta 0:00:05
#    ----------------------- ---------------- 58.6/99.8 MB 10.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 59.0/99.8 MB 10.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 59.5/99.8 MB 10.1 MB/s eta 0:00:04
#    ------------------------ --------------- 60.1/99.8 MB 10.1 MB/s eta 0:00:04
#    ------------------------ --------------- 60.5/99.8 MB 10.2 MB/s eta 0:00:04
#    ------------------------ --------------- 61.0/99.8 MB 9.9 MB/s eta 0:00:04
#    ------------------------ --------------- 61.5/99.8 MB 9.9 MB/s eta 0:00:04
#    ------------------------ --------------- 61.9/99.8 MB 9.9 MB/s eta 0:00:04
#    ------------------------- -------------- 62.5/99.8 MB 9.8 MB/s eta 0:00:04
#    ------------------------- -------------- 63.1/99.8 MB 9.8 MB/s eta 0:00:04
#    ------------------------- -------------- 63.6/99.8 MB 9.8 MB/s eta 0:00:04
#    ------------------------- -------------- 64.1/99.8 MB 10.2 MB/s eta 0:00:04
#    -------------------------- ------------- 65.0/99.8 MB 9.6 MB/s eta 0:00:04
#    -------------------------- ------------- 65.5/99.8 MB 9.8 MB/s eta 0:00:04
#    -------------------------- ------------- 66.0/99.8 MB 10.1 MB/s eta 0:00:04
#    -------------------------- ------------- 66.5/99.8 MB 9.9 MB/s eta 0:00:04
#    -------------------------- ------------- 67.0/99.8 MB 9.9 MB/s eta 0:00:04
#    --------------------------- ------------ 67.4/99.8 MB 9.8 MB/s eta 0:00:04
#    --------------------------- ------------ 67.9/99.8 MB 10.1 MB/s eta 0:00:04
#    --------------------------- ------------ 68.4/99.8 MB 10.2 MB/s eta 0:00:04
#    --------------------------- ------------ 68.9/99.8 MB 9.9 MB/s eta 0:00:04
#    --------------------------- ------------ 69.4/99.8 MB 10.1 MB/s eta 0:00:04
#    --------------------------- ------------ 69.8/99.8 MB 9.9 MB/s eta 0:00:04
#    ---------------------------- ----------- 70.2/99.8 MB 9.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 70.7/99.8 MB 9.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 71.2/99.8 MB 10.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 71.7/99.8 MB 10.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 72.1/99.8 MB 10.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 72.6/99.8 MB 10.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 73.0/99.8 MB 9.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 73.3/99.8 MB 9.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 73.5/99.8 MB 9.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 73.9/99.8 MB 9.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 74.4/99.8 MB 9.8 MB/s eta 0:00:03
#    ------------------------------ --------- 74.9/99.8 MB 9.6 MB/s eta 0:00:03
#    ------------------------------ --------- 75.4/99.8 MB 9.5 MB/s eta 0:00:03
#    ------------------------------ --------- 76.0/99.8 MB 9.5 MB/s eta 0:00:03
#    ------------------------------ --------- 76.4/99.8 MB 9.4 MB/s eta 0:00:03
#    ------------------------------ --------- 76.8/99.8 MB 9.5 MB/s eta 0:00:03
#    ------------------------------ --------- 77.3/99.8 MB 9.4 MB/s eta 0:00:03
#    ------------------------------- -------- 77.8/99.8 MB 9.4 MB/s eta 0:00:03
#    ------------------------------- -------- 78.2/99.8 MB 9.4 MB/s eta 0:00:03
#    ------------------------------- -------- 78.7/99.8 MB 9.4 MB/s eta 0:00:03
#    ------------------------------- -------- 79.2/99.8 MB 9.4 MB/s eta 0:00:03
#    ------------------------------- -------- 79.7/99.8 MB 9.4 MB/s eta 0:00:03
#    -------------------------------- ------- 80.2/99.8 MB 9.5 MB/s eta 0:00:03
#    -------------------------------- ------- 80.6/99.8 MB 9.5 MB/s eta 0:00:03
#    -------------------------------- ------- 81.2/99.8 MB 9.5 MB/s eta 0:00:02
#    -------------------------------- ------- 81.7/99.8 MB 9.5 MB/s eta 0:00:02
#    -------------------------------- ------- 82.2/99.8 MB 9.6 MB/s eta 0:00:02
#    --------------------------------- ------ 82.7/99.8 MB 9.6 MB/s eta 0:00:02
#    --------------------------------- ------ 83.3/99.8 MB 9.8 MB/s eta 0:00:02
#    --------------------------------- ------ 83.8/99.8 MB 10.4 MB/s eta 0:00:02
#    --------------------------------- ------ 84.3/99.8 MB 10.4 MB/s eta 0:00:02
#    --------------------------------- ------ 84.7/99.8 MB 10.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 85.2/99.8 MB 10.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 86.0/99.8 MB 10.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 86.5/99.8 MB 10.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 87.1/99.8 MB 10.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 87.6/99.8 MB 10.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 88.1/99.8 MB 10.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 88.6/99.8 MB 10.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.1/99.8 MB 10.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.6/99.8 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------ --- 90.1/99.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 90.7/99.8 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------ --- 91.0/99.8 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------ --- 91.4/99.8 MB 10.2 MB/s eta 0:00:01
#    ------------------------------------ --- 92.0/99.8 MB 10.2 MB/s eta 0:00:01
#    ------------------------------------- -- 92.4/99.8 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------- -- 92.9/99.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------- -- 93.5/99.8 MB 10.1 MB/s eta 0:00:01
#    ------------------------------------- -- 94.0/99.8 MB 10.1 MB/s eta 0:00:01
#    ------------------------------------- -- 94.4/99.8 MB 10.1 MB/s eta 0:00:01
#    -------------------------------------- - 94.9/99.8 MB 10.1 MB/s eta 0:00:01
#    -------------------------------------- - 95.4/99.8 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 95.8/99.8 MB 10.1 MB/s eta 0:00:01
#    -------------------------------------- - 96.3/99.8 MB 10.1 MB/s eta 0:00:01
#    -------------------------------------- - 96.8/99.8 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 97.2/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  97.8/99.8 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  98.3/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  98.8/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.2/99.8 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  99.6/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 99.8/99.8 MB 5.3 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3

# %%
from xgboost import XGBRegressor
from scipy.stats import uniform, randint

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
XGB = XGBRegressor()

# %%
params_ = {
    'n_estimators': randint(50, 200),
    'learning_rate': uniform(0.01, 0.3),
    'max_depth': randint(3, 10),
    'min_child_weight': randint(1, 6),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4)}

# %%
# Performing RandomizedSearchCV
random_xgb = RandomizedSearchCV(estimator=XGB, param_distributions=params_,
                                   n_iter=10, scoring="r2", cv=5, random_state=42)
random_xgb.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000028F34D4AC50>,
#                                         'min_child_weight': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000028F36D7DCD0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000028F37687B10>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000028F33C30290>},
#                    random_state=42, scoring='r2')

# %%
params= random_xgb.best_params_
model_xgb=random_xgb.best_estimator_

# %%
ypred_XGB=model_xgb.predict(x_test)

# %%
mse3 = mean_squared_error(y_test,ypred_XGB)
r2_= r2_score(y_test,ypred_XGB)
rmse = np.sqrt(mse3)

# %%
train_score_ = random_xgb.score(x_train,y_train)
train_score_
# Out:
# 0.6280143242149813

# %%
print(f"mean_squared_error : {mse3}")
print(f"r2_score : {r2_}")
print(f"RMSE : {rmse}")
print(f"Best Hyperparamters:{params}")
# Out:
# mean_squared_error : 839228.2478019383
# r2_score : 0.6291106915716893
# RMSE : 916.0940169010702
# Best Hyperparamters:{'colsample_bytree': 0.836965827544817, 'learning_rate': 0.02393512381599932, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 122, 'subsample': 0.6260206371941118}

# %%
# Calculating MAPE
def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - ypred_XGB) / y_true)) * 100
mape = calculate_mape(y_test, ypred_XGB)
print(f"MAPE: {mape}")
# Out:
# MAPE: 57.67014835726164

# %%
#Calculating the adjusted R-squared value
n = len(y)
k = x.shape[1] - 1
adjusted_rsquared = 1 - (1 - r2_) * (n - 1) / (n - k - 1)
print(f"R-squared: {r2_}")
print(f"Adjusted R-squared: {adjusted_rsquared}")
# Out:
# R-squared: 0.6291106915716893
# Adjusted R-squared: 0.6285440490743843

# %%
from sklearn.model_selection import cross_val_score, KFold

# %%
# Creating KFold object
KF = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
cv_scores = cross_val_score(XGB, x, y, cv=KF, scoring='neg_mean_squared_error')

# %%
# Converting negative MSE to positive RMSE
cv_rmse_scores = np.sqrt(-cv_scores)

# %%
print(f"CV RMSE Scores: {cv_rmse_scores}")
print(f"Mean RMSE: {np.mean(cv_rmse_scores)}")
# Out:
# CV RMSE Scores: [1014.41806621 1018.16901478 1052.89013792 1035.30444178 1104.89166722]
# Mean RMSE: 1045.134665579868

# %%
#now lets use the normalized x and y variables for cross val score

# %%
KF1 = KFold(n_splits=6, shuffle=True, random_state=42)

# %%
cv_scores_r2 = cross_val_score(XGB, x, y, cv=KF1, scoring='r2')

# %%
print(f'Cross-Validation R-squared Scores: {cv_scores_r2}')
print(f'Mean R-squared: {np.mean(cv_scores_r2)}')
# Out:
# Cross-Validation R-squared Scores: [0.5652413  0.54305081 0.54897256 0.55047668 0.5369215  0.52015901]
# Mean R-squared: 0.5441369762868671

# %%
# model evaluation for normalized data

# %%
random_xgb1 = RandomizedSearchCV(estimator=XGB, param_distributions=params_,
                                   n_iter=10, scoring="r2", cv=5, random_state=42)
random_xgb1.fit(xtrain2, ytrain2)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000028F34D4AC50>,
#                                         'min_child_weight': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000028F36D7DCD0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000028F37687B10>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000028F33C30290>},
#                    random_state=42, scoring='r2')

# %%
params1= random_xgb.best_params_
model_xgb1=random_xgb.best_estimator_

# %%
ypred_XGB1=model_xgb1.predict(xtest2)

# %%
mse4 = mean_squared_error(ytest2,ypred_XGB1)
r2_1= r2_score(ytest2,ypred_XGB1)

# %%
train_score_1 = random_xgb.score(xtrain2,ytrain2)
train_score_1
# Out:
# -0.0980402004238301

# %%
print(f"mean_squared_error : {mse4}")
print(f"r2_score : {r2_1}")
print(f"Best Hyperparamters:{params1}")
# Out:
# mean_squared_error : 2597715.0829767613
# r2_score : -0.14803660761240844
# Best Hyperparamters:{'colsample_bytree': 0.836965827544817, 'learning_rate': 0.02393512381599932, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 122, 'subsample': 0.6260206371941118}

# %% [markdown]
# #Ridge Regressor

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
import statsmodels.api as sm

# %%
x = train1.drop(columns=["Item_Outlet_Sales_win"])
y = train1["Item_Outlet_Sales_win"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
ridge_model = Ridge()

# %%
#hyperparameter tuning
param_grid = {'alpha': [0.1, 1.0, 10.0]}
grid_search = GridSearchCV(ridge_model, param_grid, cv=5)
grid_search.fit(xtrain, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), param_grid={'alpha': [0.1, 1.0, 10.0]})

# %%
best_alpha = grid_search.best_params_['alpha']

# %%
ridge_model = Ridge(alpha=best_alpha)
ridge_model.fit(xtrain, ytrain)
# Out:
# Ridge(alpha=10.0)

# %%
ypred= ridge_model.predict(xtest)

# %%
ridge_train= ridge_model.score(xtrain,ytrain)
ridge_train
# Out:
# 0.5033767571012246

# %%
r2 = r2_score(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
rmse = np.sqrt(mse)

# %%
#adjusted rsquare
n = len(y_test)
p = xtest.shape[1]
adj_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))

# %%
mape = np.mean(np.abs((ytest - ypred) / ytest)) * 100

# %%
cv_score = cross_val_score(ridge_model, x, y, cv=5).mean()

# %%
print(f"r_square :{r2}")
print(f"MSE :{mse}")
print(f"RMSE :{rmse}")
print(f"adj_r2 :{adj_r2}")
print(f"MAPE :{mape}")
print(f"CV_score :{cv_score}")
# Out:
# r_square :0.506199661096882
# MSE :1117344.6733684118
# RMSE :1057.045256064475
# adj_r2 :0.5021090074018266
# MAPE :86.65779229617867
# CV_score :0.5021246825168202

# %%
#normalized data
#hyperparameter tuning

param_grid_ = {'alpha': [0.1, 1.0, 10.0]}
grid_search = GridSearchCV(ridge_model, param_grid, cv=5)
grid_search.fit(xtrain2, ytrain2)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(alpha=10.0),
#              param_grid={'alpha': [0.1, 1.0, 10.0]})

# %%
best_alpha_ = grid_search.best_params_['alpha']

# %%
ridge_model_ = Ridge(alpha=best_alpha_)
ridge_model_.fit(xtrain2, ytrain2)
# Out:
# Ridge()

# %%
ypred_= ridge_model_.predict(xtest2)

# %%
r2_ = r2_score(ytest2, ypred_)
mse_ = mean_squared_error(ytest2, ypred_)
rmse_ = np.sqrt(mse)

# %%
#adjusted rsquare
n = len(ytest2)
p = xtest2.shape[1]
adj_r2_ = 1 - ((1 - r2_) * (n - 1) / (n - p - 1))

# %%
cv_score_ = cross_val_score(ridge_model, x, y, cv=5).mean()

# %%
print(f"r2_score: {r2_}")
print(f"adj_r2 : {adj_r2_}")
print(f"CV score: {cv_score_}")
# Out:
# r2_score: 0.5062097538400154
# adj_r2 : 0.5021191837534831
# CV score: 0.5021246825168202

# %% [markdown]
# #Lasso Regressor

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LassoCV, Lasso

# %%
lasso_cv = LassoCV(alphas=np.logspace(-4, 4, 100), cv=5)
lasso_cv.fit(x_train, y_train)
# Out:
# LassoCV(alphas=array([1.00000000e-04, 1.20450354e-04, 1.45082878e-04, 1.74752840e-04,
#        2.10490414e-04, 2.53536449e-04, 3.05385551e-04, 3.67837977e-04,
#        4.43062146e-04, 5.33669923e-04, 6.42807312e-04, 7.74263683e-04,
#        9.32603347e-04, 1.12332403e-03, 1.35304777e-03, 1.62975083e-03,
#        1.96304065e-03, 2.36448941e-03, 2.84803587e-03, 3.43046929e-03,
#        4.13201240e-03, 4.97702356e-0...
#        1.38488637e+02, 1.66810054e+02, 2.00923300e+02, 2.42012826e+02,
#        2.91505306e+02, 3.51119173e+02, 4.22924287e+02, 5.09413801e+02,
#        6.13590727e+02, 7.39072203e+02, 8.90215085e+02, 1.07226722e+03,
#        1.29154967e+03, 1.55567614e+03, 1.87381742e+03, 2.25701972e+03,
#        2.71858824e+03, 3.27454916e+03, 3.94420606e+03, 4.75081016e+03,
#        5.72236766e+03, 6.89261210e+03, 8.30217568e+03, 1.00000000e+04]),
#         cv=5)

# %%
alpha = lasso_cv.alpha_

# %%
lasso_model = Lasso(alpha=alpha)

# %%
lasso_model.fit(x_train, y_train)
# Out:
# Lasso(alpha=2.310129700083163)

# %%
y_pred = lasso_model.predict(x_test)

# %%
lasso_train= lasso_model.score(x_train,y_train)
lasso_train
# Out:
# 0.5033088239050499

# %%
r2 = r2_score(y_test, y_pred)
adj_r2 = 1 - (1 - r2) * (len(y_test) - 1) / (len(y_test) - x_test.shape[1] - 1)
mse = mean_squared_error(y_test, y_pred)
rmse1 = np.sqrt(mse)

# %%
cross_val_r2_scores = cross_val_score(lasso_model, x_train, y_train, cv=5, scoring='r2')
lasso_cv= cross_val_r2_scores.mean()

# %%
print(f"R2 Score: {r2}")
print(f"Adjusted R2 Score: {adj_r2}")
print(f"MSE: {mse}")
print(f"Cross-Validation R2 Scores: {cross_val_r2_scores}")
print(f"CV : {lasso_cv}")
print(f"RMSE: {rmse1}")
# Out:
# R2 Score: 0.5063624714085178
# Adjusted R2 Score: 0.5022731664379374
# MSE: 1116976.275009513
# Cross-Validation R2 Scores: [0.50248169 0.49459702 0.50375245 0.50815643 0.49789956]
# CV : 0.5013774312640283
# RMSE: 1056.8709831429344

# %%
#normalized data

# %%
lasso_cv_ = LassoCV(alphas=np.logspace(-4, 4, 100), cv=5)
lasso_cv_.fit(xtrain2, ytrain2)
# Out:
# LassoCV(alphas=array([1.00000000e-04, 1.20450354e-04, 1.45082878e-04, 1.74752840e-04,
#        2.10490414e-04, 2.53536449e-04, 3.05385551e-04, 3.67837977e-04,
#        4.43062146e-04, 5.33669923e-04, 6.42807312e-04, 7.74263683e-04,
#        9.32603347e-04, 1.12332403e-03, 1.35304777e-03, 1.62975083e-03,
#        1.96304065e-03, 2.36448941e-03, 2.84803587e-03, 3.43046929e-03,
#        4.13201240e-03, 4.97702356e-0...
#        1.38488637e+02, 1.66810054e+02, 2.00923300e+02, 2.42012826e+02,
#        2.91505306e+02, 3.51119173e+02, 4.22924287e+02, 5.09413801e+02,
#        6.13590727e+02, 7.39072203e+02, 8.90215085e+02, 1.07226722e+03,
#        1.29154967e+03, 1.55567614e+03, 1.87381742e+03, 2.25701972e+03,
#        2.71858824e+03, 3.27454916e+03, 3.94420606e+03, 4.75081016e+03,
#        5.72236766e+03, 6.89261210e+03, 8.30217568e+03, 1.00000000e+04]),
#         cv=5)

# %%
#selected parameters
alpha_ = lasso_cv_.alpha_

# %%
#lasso model creation
lasso_model_ = Lasso(alpha=alpha_)

# %%
lasso_model_.fit(xtrain2, ytrain2)
# Out:
# Lasso(alpha=1.0974987654930568)

# %%
y_pred_ = lasso_model_.predict(xtest2)

# %%
r2_1 = r2_score(ytest2, y_pred_)
adj_r2_1 = 1 - (1 - r2_1) * (len(ytest2) - 1) / (len(ytest2) - xtest2.shape[1] - 1)
mse_1 = mean_squared_error(ytest2, y_pred_)

# %%
_cross_val_r2_scores = cross_val_score(lasso_model_, xtrain2, ytrain2, cv=5, scoring='r2')

# %%
print(f"r2_score: {r2_1}")
print(f"adjusted r2 score: {adj_r2_1}")
print(f"mse: {mse_1}")
print(f"cross_val_score: {_cross_val_r2_scores}")
# Out:
# r2_score: 0.506518595307867
# adjusted r2 score: 0.5024305836713641
# mse: 1116623.0063023448
# cross_val_score: [0.5026752  0.4948576  0.50353327 0.50778282 0.49786372]

# %%
#mape
#show 3 best models in excel
#cv score for all 3 models
#all models with rmse, cv, r2, adjusted r2

# %%
#hyperparameter tuning

# %% [markdown]
# #5 MODELS

# %%
RandomForest_data = {
    'Model': ['Random Forest'],
    'Train Score': [71],
    'MSE': [868865],
    'RMSE': [932],
    'R2 Score': [61.60],
    'Adjusted R2 Score': [61.54],
    'Cross-Validation Score': [60.32],
    'Normalized MSE': [849344.72],
    'Normalized RMSE': [921.59],
    'Normalized R2 Score': [62.46],
    'Normalized Adjusted R2 Score': [62.40],
    'Normalized Cross-Validation Score': [60.44],
    'MAPE': [51.12]
}
# Data for SVM
SVM_data = {
    'Model': ['SVM'],
    'Train Score': [45.34],
    'MSE': [1215757.74],
    'RMSE': [1102.61],
    'R2 Score': [46.27],
    'Adjusted R2 Score': [46.18],
    'Cross-Validation Score': [45.21],
    'MAPE': [79.29],
    'Normalized MSE': [1717185.93],
    'Normalized RMSE': [1102.61],
    'Normalized R2 Score': [24.11],
    'Normalized Adjusted R2 Score': [23.99]
}
# Data for XGBoost
XGBOOST_data = {
    'Model': ['XGBoost'],
    'Train Score': [62.99],
    'MSE': [837063.22],
    'R2 Score': [63.00],
    'MAPE': [57.10],
    'Adjusted R2 Score': [62.95],
    'CV RMSE': [1045.13],
    'Cross-Validation Score': [54.41],
    'RMSE': [914.911]
}
RIDGE_data = {
    "Model": ["Ridge"],
    "Train Score": [50.33],
    "MSE": [1117344.67],
    "R2 Score": [50.61],
    "MAPE": [86.65],
    "Adjusted R2 Score": [50.21],
    "Cross-Validation Score":[50.21],
    "Normalized R2 Score": [50.62],
    "Normalized Adjusted R2 Score": [50.21],
    "Normalized Cross-Validation Score": [50.21],
    "RMSE":[1057.04]


}
LASSO_data = {
    "Model": ["Lasso"],
    "MSE": [1116976],
    "R2 Score": [50.62],
    "Adjusted R2 Score": [50.22],
    "Cross-Validation Score":[50],
    "Normalized R2 Score": [50.65],
    "Normalized Adjusted R2 Score":[50.24],
    "Normalized MSE": [1116623.00],
    "Train Score": [50.33],
    "RMSE": [1056.87]
}

# %%
RANDOMFOREST_df = pd.DataFrame(RandomForest_data)
SVM_df = pd.DataFrame(SVM_data)
XGBOOST_df = pd.DataFrame(XGBOOST_data)
LASSO_df = pd.DataFrame(LASSO_data)
RIDGE_df = pd.DataFrame(RIDGE_data)
# Concatenate DataFrames
summary_table = pd.concat([RANDOMFOREST_df, SVM_df, XGBOOST_df, LASSO_df, RIDGE_df], ignore_index=True)

# %%
summary_table
# Out:
#            Model  Train Score         MSE      RMSE  R2 Score  \
# 0  Random Forest        71.00   868865.00   932.000     61.60
# 1            SVM        45.34  1215757.74  1102.610     46.27
# 2        XGBoost        62.99   837063.22   914.911     63.00
# 3          Lasso        50.33  1116976.00  1056.870     50.62
# 4          Ridge        50.33  1117344.67  1057.040     50.61
#
#    Adjusted R2 Score  Cross-Validation Score  Normalized MSE  Normalized RMSE  \
# 0              61.54                   60.32       849344.72           921.59
# 1              46.18                   45.21      1717185.93          1102.61
# 2              62.95                   54.41             NaN              NaN
# 3              50.22                   50.00      1116623.00              NaN
# 4              50.21                   50.21             NaN              NaN
#
#    Normalized R2 Score  Normalized Adjusted R2 Score  \
# 0                62.46                         62.40
# 1                24.11                         23.99
# 2                  NaN                           NaN
# 3                50.65                         50.24
# 4                50.62                         50.21
#
#    Normalized Cross-Validation Score   MAPE  CV RMSE
# 0                              60.44  51.12      NaN
# 1                                NaN  79.29      NaN
# 2                                NaN  57.10  1045.13
# 3                                NaN    NaN      NaN
# 4                              50.21  86.65      NaN

# %%
import joblib 
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor()

# %%
joblib.dump(RF,'RF.sav')
# Out:
# ['RF.sav']

# %%
loaded_model = joblib.load('RF.sav')
